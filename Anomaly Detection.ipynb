# %%
from pycaret.anomaly import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
data = pd.read_csv('./HealthCare/Train_Inpatientdata.csv',nrows=10000)
out_data = pd.read_csv("./HealthCare/Train_Outpatientdata.csv",nrows=10000)
labels = pd.read_csv('./HealthCare/Train.csv')
y = labels.merge(data)['PotentialFraud'].eq('Yes').mul(1)
out_y = labels.merge(out_data)['PotentialFraud'].eq('Yes').mul(1)

# %%
print("Ratio of Anomalies in Inpatient Data",(len(y[y==1])/len(y)))
print("Ratio of Anomalies in Outpatient Data",(len(out_y[out_y==1])/len(out_y)))
# Out:
# Ratio of Anomalies in Inpatient Data 0.571
# Ratio of Anomalies in Outpatient Data 0.3505

# %%
in_ano_ratio = 0.571
out_ano_ratio = 0.3505

# %%
labels
# Out:
#       Provider PotentialFraud
# 0     PRV51001             No
# 1     PRV51003            Yes
# 2     PRV51004             No
# 3     PRV51005            Yes
# 4     PRV51007             No
# ...        ...            ...
# 5405  PRV57759             No
# 5406  PRV57760             No
# 5407  PRV57761             No
# 5408  PRV57762             No
# 5409  PRV57763             No
#
# [5410 rows x 2 columns]

# %%
ano1 = setup(data = data)
# Out:
# <style  type="text/css" >
# #T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row2_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row0_col1" class="data row0 col1" >4813</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row1_col0" class="data row1 col0" >Original Data</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row1_col1" class="data row1 col1" >(10000, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row2_col0" class="data row2 col0" >Missing Values</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row2_col1" class="data row2 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row3_col0" class="data row3 col0" >Numeric Features</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row3_col1" class="data row3 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row4_col0" class="data row4 col0" >Categorical Features</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row4_col1" class="data row4 col1" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row5_col0" class="data row5 col0" >Ordinal Features</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row6_col0" class="data row6 col0" >High Cardinality Features</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row7_col0" class="data row7 col0" >High Cardinality Method</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row7_col1" class="data row7 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row8_col0" class="data row8 col0" >Transformed Data</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row8_col1" class="data row8 col1" >(10000, 42337)</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row9_col0" class="data row9 col0" >CPU Jobs</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row9_col1" class="data row9 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row10_col0" class="data row10 col0" >Use GPU</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row10_col1" class="data row10 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row11_col0" class="data row11 col0" >Log Experiment</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row11_col1" class="data row11 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row12_col0" class="data row12 col0" >Experiment Name</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row12_col1" class="data row12 col1" >anomaly-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row13_col0" class="data row13 col0" >USI</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row13_col1" class="data row13 col1" >33e3</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row14_col0" class="data row14 col0" >Imputation Type</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row14_col1" class="data row14 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row15_col0" class="data row15 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row15_col1" class="data row15 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row16_col0" class="data row16 col0" >Numeric Imputer</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row16_col1" class="data row16 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row17_col0" class="data row17 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row17_col1" class="data row17 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_808b5d76_3f5d_11eb_958a_bbfcd05864e3row18_col0" class="data row18 col0" >Categorical Imputer</td>
#                         <td id="T_808b5d76_3

# %% [markdown]
# ## Isolation Forest

# %%
## Tested Different Varitations of anomaly fraction
## Default 0.05 accuracy 63% but less anomalies were detected
## Actual 0.35  accuracy 52% around 1200 anomalies detected out of 10000

iforest = create_model('iforest',fraction=in_ano_ratio)

# %%
ifor_pred = predict_model(iforest,data=data)

# %%
y_pred = ifor_pred['Anomaly']

# %%
print("Isolation Forest Accuracy: ",accuracy_score(y,y_pred))
print(confusion_matrix(y,y_pred))
# Out:
# Isolation Forest Accuracy:  0.5156
# [[1868 2422]
#  [2422 3288]]

# %% [markdown]
# ## KNN Anomaly Detection

# %%
knn = create_model('knn',fraction = in_ano_ratio)

# %%
knn_pred = predict_model(knn,data=data)

# %%
knn_pred[knn_pred['Anomaly']==1]
# Out:
#          BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0     BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1     BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 3     BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4     BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# 5     BENE11017  CLM70950   2009-10-06  2009-10-12  PRV54986
# ...         ...       ...          ...         ...       ...
# 9990  BENE47813  CLM54804   2009-06-09  2009-06-10  PRV55128
# 9994  BENE47824  CLM48173   2009-04-23  2009-05-01  PRV53857
# 9997  BENE47834  CLM31789   2008-12-31  2009-01-02  PRV55396
# 9998  BENE47841  CLM53039   2009-05-28  2009-05-31  PRV51031
# 9999  BENE47843  CLM49032   2009-04-29  2009-05-07  PRV55196
#
#       InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      26000          PHY390922                NaN
# 1                       5000          PHY318495          PHY318495
# 3                       5000          PHY369659          PHY392961
# 4                      10000          PHY379376          PHY398258
# 5                       8000          PHY402711          PHY402711
# ...                      ...                ...                ...
# 9990                    3000          PHY424816          PHY424816
# 9994                    5000          PHY342421          PHY340277
# 9997                    8000          PHY382801          PHY382801
# 9998                   14000          PHY409001                NaN
# 9999                    5000          PHY328630          PHY423669
#
#      OtherPhysician AdmissionDt  ... ClmDiagnosisCode_9  ClmDiagnosisCode_10  \
# 0               NaN  2009-04-12  ...               5849                  NaN
# 1               NaN  2009-08-31  ...                NaN                  NaN
# 3         PHY349768  2009-02-14  ...               4019                  NaN
# 4               NaN  2009-08-13  ...              20300                  NaN
# 5         PHY402711  2009-10-06  ...              25002                  NaN
# ...             ...         ...  ...                ...                  ...
# 9990      PHY424816  2009-06-09  ...              41401                  NaN
# 9994            NaN  2009-04-23  ...              25000                  NaN
# 9997            NaN  2008-12-31  ...                NaN                  NaN
# 9998            NaN  2009-05-28  ...               7993                  NaN
# 9999            NaN  2009-04-29  ...               5559                  NaN
#
#      ClmProcedureCode_1 ClmProcedureCode_2 ClmProcedureCode_3  \
# 0                   NaN                NaN                NaN
# 1                7092.0                NaN                NaN
# 3                 331.0                NaN                NaN
# 4                3893.0                NaN                NaN
# 5                 863.0                NaN                NaN
# ...                 ...                ...                ...
# 9990             8872.0                NaN                NaN
# 9994             4443.0             4019.0              496.0
# 9997             6021.0                NaN                NaN
# 9998                NaN                NaN                NaN
# 9999             8952.0                NaN                NaN
#
#      ClmProcedureCode_4 ClmProcedureCode_5 ClmProcedureCode_6 Anomaly  \
# 0                   NaN                NaN                NaN       1
# 1                   NaN                NaN                NaN       1
# 3                   NaN                NaN                NaN       1
# 4                   NaN                NaN                NaN       1
# 5                   NaN                NaN                NaN       1
# ...                 ...                ...                ...     ...
# 9990                NaN                NaN                NaN       1
# 9994             2724.0                NaN                NaN       1
# 9997                NaN                NaN                NaN       1
# 9998                NaN                NaN                NaN       1
# 9999                NaN                NaN                NaN       1
#
#      Anomaly_Score
# 0         6.782330
# 1       262.875901
# 3         6.928203
# 4         6.633250
# 5       258.089132
# ...            ...
# 9990      7.071068
# 9994   3519.820592
# 9997    151.296799
# 9998      6.633250
# 9999      9.949874
#
# [5551 rows x 32 columns]

# %%
print("KNN Accuracy: ",accuracy_score(y,knn_pred['Anomaly']))
print(confusion_matrix(y,knn_pred['Anomaly']))
# Out:
# KNN Accuracy:  0.5115
# [[1927 2363]
#  [2522 3188]]

# %% [markdown]
# ## Angle Based Outlier Detection

# %%
abod_model = create_model('abod',fraction = in_ano_ratio)

# %%
abod_pred = predict_model(abod_model,data=data)

# %%
abod_pred.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_9  ClmDiagnosisCode_10  \
# 0            NaN  2009-04-12  ...               5849                  NaN
# 1            NaN  2009-08-31  ...                NaN                  NaN
# 2      PHY324689  2009-09-17  ...                NaN                  NaN
# 3      PHY349768  2009-02-14  ...               4019                  NaN
# 4            NaN  2009-08-13  ...              20300                  NaN
#
#   ClmProcedureCode_1 ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4  \
# 0                NaN                NaN                NaN                NaN
# 1             7092.0                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3              331.0                NaN                NaN                NaN
# 4             3893.0                NaN                NaN                NaN
#
#   ClmProcedureCode_5 ClmProcedureCode_6 Anomaly Anomaly_Score
# 0                NaN                NaN       1 -1.240785e-07
# 1                NaN                NaN       1 -1.290437e-12
# 2                NaN                NaN       0 -5.298959e-06
# 3                NaN                NaN       1 -5.145208e-08
# 4                NaN                NaN       1 -1.044975e-06
#
# [5 rows x 32 columns]

# %%
print("ABOD Accuracy: ",accuracy_score(y,abod_pred['Anomaly']))
print(confusion_matrix(y,abod_pred['Anomaly']))
# Out:
# ABOD Accuracy:  0.5245
# [[1615 2675]
#  [2080 3630]]

# %% [markdown]
# ## Cluster Based

# %%
cluster_model = create_model('cluster',fraction = in_ano_ratio)

# %%
cluster_pred = predict_model(cluster_model,data=data)

# %%
print("Cluster Accuracy: ",accuracy_score(y,cluster_pred['Anomaly']))
print(confusion_matrix(y,cluster_pred['Anomaly']))
# Out:
# Cluster Accuracy:  0.504
# [[1811 2479]
#  [2481 3229]]

# %% [markdown]
# ## Stochastic

# %%
stochastic_model = create_model('sos',fraction = in_ano_ratio)

# %%
sto_pred = predict_model(stochastic_model,data=data)

# %%
print("Stochastic Accuracy: ",accuracy_score(y,sto_pred['Anomaly']))
print(confusion_matrix(y,sto_pred['Anomaly']))
# Out:
# Stochastic Accuracy:  0.429
# [[4290    0]
#  [5710    0]]

# %% [markdown]
# ## Minimum Covariance

# %%
mcd_model = create_model('mcd',fraction = in_ano_ratio)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                        10:13:58
# Status     . . . . . . . . . . . . . . . . . .          Fitting 0.571 Fraction
# Estimator  . . . . . . . . . . . . . . . . . .  Minimum Covariance Determinant

# %%
mcd_pred = predict_model(mcd_model,data=data)

# %%
print("Minumum Covariance Accuracy: ",accuracy_score(y,mcd_pred['Anomaly']))
print(confusion_matrix(y,mcd_pred['Anomaly']))

# %% [markdown]
# ####  Anomaly Detection Deosn't seems to be a good tool for detcting anomalies in this dataset.
# ####  Either we need to change technique for detection of fraud, or we need to mould our data

# %% [markdown]
# # For OutPatient Data

# %%
ano1 = setup(data = out_data)

# %% [markdown]
# ## Isolation Forest

# %%
iforest = create_model('iforest',fraction=out_ano_ratio)

# %%
ifor_pred = predict_model(iforest,data=out_data)
y_pred = ifor_pred['Anomaly']
print("Isolation Forest Accuracy: ",accuracy_score(y,y_pred))
print(confusion_matrix(y,y_pred))

# %% [markdown]
# ## KNN Anomaly Detection

# %%
knn = create_model('knn',fraction=out_ano_ratio)
knn_pred = predict_model(knn,data=out_data) 
print("KNN Accuracy: ",accuracy_score(y,knn_pred['Anomaly']))
print(confusion_matrix(y,knn_pred['Anomaly']))

# %% [markdown]
# ## Angle Based Outlier Detection

# %%
abod_model = create_model('abod',fraction=out_ano_ratio)
abod_pred = predict_model(abod_model,data=out_data) 
print("ABOD Accuracy: ",accuracy_score(y,abod_pred['Anomaly']))
print(confusion_matrix(y,abod_pred['Anomaly']))

# %% [markdown]
# ## Cluster Based

# %%
cluster_model = create_model('cluster',fraction=out_ano_ratio)
cluster_pred = predict_model(cluster_model,data=out_data) 
print("Cluster Accuracy: ",accuracy_score(y,cluster_pred['Anomaly']))
print(confusion_matrix(y,cluster_pred['Anomaly']))

# %% [markdown]
# ## Stochastic

# %%
stochastic_model = create_model('sos',fraction=out_ano_ratio)
sto_pred = predict_model(stochastic_model,data=out_data)
print("Stochastic Accuracy: ",accuracy_score(y,sto_pred['Anomaly']))
print(confusion_matrix(y,sto_pred['Anomaly']))

# %% [markdown]
# ## Minimum Corvarince

# %%
mcd_model = create_model('mcd',fraction=out_ano_ratio)
mcd_pred = predict_model(mcd_model,data=out_data)
print("Minumum Covariance Accuracy: ",accuracy_score(y,mcd_pred['Anomaly']))
print(confusion_matrix(y,mcd_pred['Anomaly']))
